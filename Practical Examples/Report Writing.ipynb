# %% [markdown]
# # Assignment 1

# %% [markdown]
# Name : TaeHoon
#
# Date : 2024 August

# %% [markdown]
# ==================================================

# %% [markdown]
# ![image.png](attachment:a3d22b74-e97c-4ae6-8e19-2ea96ef27751.png)

# %% [markdown]
# The following equations are plotted for the corresponding domains:
#
# $f(x) = \frac{1}{10}x^2$ for $x \in[0, 1.5) $
#
# $f(x) = \sum_{n=1,3,5..}^{N}{\frac{4}{\pi n} \text{sin}(\frac{2\pi n(x-1.5)}{T})}$ for $x \in [1.5, 3]$

# %% [markdown]
# $
# \begin{cases}
# a \\
# b
# \end{cases}
# $

# %% [markdown]
# $
# \begin{cases}
# f(x) = \frac{1}{10}x^2 \text{for} x \in[0, 1.5) \\
# f(x) = \sum_{n=1,3,5..}^{N}{\frac{4}{\pi n} \text{sin}(\frac{2\pi n(x-1.5)}{T})} \text{for} x \in[1.5, 3]
# \end{cases}
# $

# %%
# \begin{align} 
# & 기준으로 정렬
# \end{align}

# %% [markdown]
# $
# \begin{align}
# \begin{cases}
# f(x) = \frac{1}{10}x^2 & \text{for} x \in[0, 1.5) \\
# f(x) = \sum_{n=1,3,5..}^{N}{\frac{4}{\pi n} \text{sin}(\frac{2\pi n(x-1.5)}{T})} & \text{for} x \in[1.5, 3]
# \end{cases}
# \end{align}
# $

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# calculate the first equation
dx = 0.01
x1 = np.arange(0, 1.5, dx)
y1 = 1/10*x1**2

# %%
# calculate the second equation
x2 = np.arange(1.5, 3+dx, dx)
N = 50
T = 1
y2 = np.zeros(x2.shape)
for n in range(N):
    if n%2 == 1:
        series = (4/(np.pi*n))*np.sin((2*np.pi*n*(x2-1.5))/T)
        y2 = y2 + series

# %%
# plot
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Piecewise Functions')
# Out:
# Text(0.5, 1.0, 'Piecewise Functions')
