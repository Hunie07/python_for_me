# %%
if True:
    print('Hello, World!')
# Out:
# Hello, World!

# %%
if False:
    print('Hello, World!')

# %% [markdown]
# ▶ Control Flow

# %% [markdown]
# ![image.png](attachment:ae71ddaa-119c-428c-a2f5-edd4fee9b95f.png)

# %%
# read x
x = input('Type any number: ')

# check if integer
while x.isdigit() != True:
    x = input('Try again: ')
    
# add x and 1
y = int(x) + 1
    
# print result
print(f'Result is {y}')
# Out:
# Type any number:  a
# Try again:  b
# Try again:  3
# Result is 4

# %%
# if-elif-else
x = int(input('What is your age?: '))
if x >= 18:
    print('You can take a license test')
elif x >= 15 and x < 18:
    print('You can get a permit')
else:
    print('Below age 15, no permit/license allowed')
# Out:
# What is your age?:  10
# Below age 15, no permit/license allowed

# %%
# if-else
vip_list = ['Kepler', 'Newton', 'Euler']
name_check = input('Provide name: ')
if name_check in vip_list:
    print('Welcome, Mr. '+name_check)
    print('Please, come in')
else:
    print('Not on the list')
    print('Wait here')
# Out:
# Provide name:  Hunie
# Not on the list
# Wait here
